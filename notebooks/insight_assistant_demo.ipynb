# %% [markdown]
# # 🤖 AI Insight Assistant Demo\n\nThis notebook demonstrates the new `%%ai_insight` magic command, which provides AI-powered insights and visualization suggestions for your DataFrames.

# %% [markdown]
# ## 1. Setup\n\nFirst, let's load the AI assistant extension. This will give us access to the new magic command.

# %%
# %load_ext ai_assistant.magic_commands

# %% [markdown]
# ## 2. Load Sample Data\n\nWe'll create a sample DataFrame to work with. This DataFrame contains mock sales data.

# %%
import pandas as pd\nimport numpy as np\n\ndata = {\n    'Date': pd.to_datetime(pd.date_range(start='2023-01-01', periods=100, freq='D')),\n    'Category': np.random.choice(['Electronics', 'Clothing', 'Groceries', 'Books'], 100),\n    'Sales': np.random.randint(100, 1000, 100),\n    'Customers': np.random.randint(10, 50, 100)\n}\ndf = pd.DataFrame(data)\ndf.head()

# %% [markdown]
# ## 3. Generate Insights\n\nNow, we'll use the `%%ai_insight` command to get an analysis of our DataFrame. The command will provide a summary and suggest interactive plots.

# %%
# %%ai_insight\ndf

# %% [markdown]
# ## 4. Interacting with Suggestions\n\nClick the **'Generate Plot'** buttons above. A new cell will be created below with the necessary code, and the plot will be generated automatically.
